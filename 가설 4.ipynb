# %% [markdown]
# # 가설 4: RAG 검색 결과 → 자연어 포매팅
#
# ## 배경
#
# 가설 3에서 확인한 사실:
# - **3-1/3-2 (직접 검색)**: 오류 시그니처/교정 쌍을 알면 정밀도가 매우 높음
# - **3-3 (2단계 검색)**: BM25/벡터 후보로부터 오류 패턴을 역추정하는 방식은 노이즈에 취약
#   - 핵심 병목: 입력 문장의 오류 유형을 모르는 상태에서 역추정하는 과정
#
# ## 새 접근
#
# BM25/벡터로 유사 문장을 찾고, 그 문장의 오류 주석을 **자연어로 포매팅**하여 피드백 LLM의 컨텍스트로 제공한다.
#
# ## 가설
#
# > 말뭉치의 교정 사례를 자연어로 제시하면, 하드코딩 규칙 없이도 LLM이 올바른 교정 방향을 잡을 수 있다.
#
# 이 노트북에서는 **검색 → 포매팅**까지만 실험한다. 포매팅된 결과는 `{{rag_examples}}`에 주입될 예정.

# %%
from opensearchpy import OpenSearch
from sentence_transformers import SentenceTransformer

client = OpenSearch(
    hosts=[{"host": "172.30.1.81", "port": 9200}],
    http_auth=None,
    use_ssl=False,
    verify_certs=False,
)

INDEX_NAME = "korean_test"

model = SentenceTransformer("../model/KURE-v1", local_files_only=True)
print(f"임베딩 모델 로드 완료 (dim={model.get_sentence_embedding_dimension()})")
print(f"OpenSearch 연결: {client.info()['version']['number']}")
# Out:
# Loading weights: 100%|███████████████████████████████████████████████████████████████| 391/391 [00:01<00:00, 366.26it/s, Materializing param=pooler.dense.weight]
# 임베딩 모델 로드 완료 (dim=1024)
# OpenSearch 연결: 2.18.0

# %%
def search_hybrid(query_text: str, k: int = 10) -> list[dict]:
    """BM25 + 벡터 검색 후 결과 병합. 오류 문장만 반환."""
    # BM25 검색
    bm25_query = {
        "size": k,
        "query": {"match": {"original_text": query_text}},
        "_source": ["original_text", "error_signatures", "correction_pairs", "has_error"],
    }
    bm25_resp = client.search(index=INDEX_NAME, body=bm25_query)

    # 벡터 검색
    query_vec = model.encode(query_text).tolist()
    knn_query = {
        "size": k,
        "query": {"knn": {"embedding": {"vector": query_vec, "k": k}}},
        "_source": ["original_text", "error_signatures", "correction_pairs", "has_error"],
    }
    knn_resp = client.search(index=INDEX_NAME, body=knn_query)

    # 병합: dict by _id, 중복 제거
    merged = {}
    for hit in bm25_resp["hits"]["hits"] + knn_resp["hits"]["hits"]:
        merged[hit["_id"]] = hit["_source"]

    # 오류 문장만 필터
    results = []
    for doc_id, src in merged.items():
        if src.get("has_error") is True:
            results.append({
                "original_text": src["original_text"],
                "error_signatures": src.get("error_signatures", []),
                "correction_pairs": src.get("correction_pairs", []),
            })

    return results

print("search_hybrid() 정의 완료")
# Out:
# search_hybrid() 정의 완료

# %%
# 품사 태그 → 한국어 이름 매핑
POS_NAMES = {
    "NNG": "명사", "NNP": "고유명사", "NNB": "의존명사", "NP": "대명사",
    "VV": "동사", "VA": "형용사", "VX": "보조용언", "VCP": "지정사",
    "JKS": "주격 조사", "JKO": "목적격 조사", "JKB": "부사격 조사",
    "JKG": "관형격 조사", "JKC": "보격 조사", "JX": "보조사", "JC": "접속 조사",
    "EP": "선어말 어미", "EF": "종결 어미", "EC": "연결 어미", "ETM": "관형사형 어미",
    "MAG": "부사", "MM": "관형사",
    "XSV": "동사 접미사", "XSA": "형용사 접미사", "XSN": "명사 접미사",
}

# 오류 양상 → 한국어 이름 매핑
ERROR_TYPE_NAMES = {
    "REP": "바꿈", "MIF": "철자 오류", "OM": "빠짐", "ADD": "불필요한 추가",
}


def format_correction_pair(pair_str: str) -> str:
    """교정 쌍 문자열을 자연어로 변환.

    입력: '를/JKO→와/JKB'
    출력: '를' → '와' (목적격 조사를 부사격 조사로 바꿈)
    """
    try:
        left, right = pair_str.split("→")
        orig_morph, orig_pos = left.rsplit("/", 1)
        corr_morph, corr_pos = right.rsplit("/", 1)
    except ValueError:
        return pair_str  # 파싱 실패 시 원본 반환

    orig_pos_name = POS_NAMES.get(orig_pos, orig_pos)
    corr_pos_name = POS_NAMES.get(corr_pos, corr_pos)

    # 오류 양상 결정
    if orig_pos == corr_pos:
        action = ERROR_TYPE_NAMES.get("MIF", "철자 오류")
    else:
        action = ERROR_TYPE_NAMES.get("REP", "바꿈")

    return f"'{orig_morph}' → '{corr_morph}' ({orig_pos_name}를 {corr_pos_name}로 {action})"


def format_hit(hit: dict) -> str:
    """검색 결과 한 건을 자연어 블록으로 변환."""
    lines = [f'문장: "{hit["original_text"]}"']
    for pair_str in hit.get("correction_pairs", []):
        lines.append(f"교정: {format_correction_pair(pair_str)}")
    return "\n".join(lines)


def format_rag_examples(hits: list[dict], max_examples: int = 3) -> str:
    """상위 N개 히트를 포매팅하여 하나의 문자열로 결합."""
    if not hits:
        return ""

    blocks = []
    for i, hit in enumerate(hits[:max_examples]):
        formatted = format_hit(hit)
        # 번호 붙이기: 각 줄 들여쓰기
        formatted_lines = formatted.split("\n")
        numbered = f"{i + 1}. {formatted_lines[0]}"
        for line in formatted_lines[1:]:
            numbered += f"\n   {line}"
        blocks.append(numbered)

    return "[유사 오류 사례]\n" + "\n\n".join(blocks)


# 단위 테스트
print(format_correction_pair("를/JKO→와/JKB"))
print(format_correction_pair("뱡완/NNG→병원/NNG"))
print()
print(format_hit({
    "original_text": "저는 친구를 같이 영화를 봤어요.",
    "correction_pairs": ["를/JKO→와/JKB"],
}))
# Out:
# '를' → '와' (목적격 조사를 부사격 조사로 바꿈)
# '뱡완' → '병원' (명사를 명사로 철자 오류)
#
# 문장: "저는 친구를 같이 영화를 봤어요."
# 교정: '를' → '와' (목적격 조사를 부사격 조사로 바꿈)

# %% [markdown]
# ## 테스트
#
# 가설 3과 동일한 4개 테스트 문장으로 검색 → 포매팅 파이프라인을 실행한다.
#
# | # | 문장 | 오류 유형 |
# |---|------|----------|
# | 1 | 저는 어제 뱡완에 갔어요. | 오타 (뱡완→병원) |
# | 2 | 저는 친구를 같이 영화를 봤어요. | 조사 (를→와) |
# | 3 | 공부가 힘든입니다. | 어미 (힘든입니다→힘듭니다) |
# | 4 | 내 월꺼 아네 있는데요 | 복합 (월꺼→워커, 아네→안에) |

# %%
test_sentences = [
    "저는 어제 뱡완에 갔어요.",
    "저는 친구를 같이 영화를 봤어요.",
    "공부가 힘든입니다.",
    "내 월꺼 아네 있는데요",
]

for sentence in test_sentences:
    print("=" * 70)
    print(f"입력: {sentence}")
    print()

    hits = search_hybrid(sentence, k=10)
    print(f"검색 결과: {len(hits)}건 (오류 문장만)")

    # raw 검색 결과 출력
    print("\n--- Raw 검색 결과 (상위 3건) ---")
    for i, hit in enumerate(hits[:3]):
        print(f"  [{i+1}] {hit['original_text']}")
        print(f"      시그니처: {hit['error_signatures']}")
        print(f"      교정 쌍: {hit['correction_pairs']}")

    # 포매팅 결과 출력
    formatted = format_rag_examples(hits, max_examples=3)
    print("\n--- 포매팅 결과 ---")
    if formatted:
        print(formatted)
    else:
        print("(검색 결과 없음)")
    print()
# Out:
# ...
# 입력: 저는 어제 뱡완에 갔어요.
#
# 검색 결과: 10건 (오류 문장만)
#
# --- Raw 검색 결과 (상위 3건) ---
#   [1] 저는 네팔에 보커라 갔어요.
#       시그니처: ['FAP:REP', 'FAP:OM']
#       교정 쌍: ['에/JKB→의/JKG', '∅→에/JKB']
#   [2] 좀 비군해서 저는 집에 갔어요.
#       시그니처: ['CNNG:MIF']
#       교정 쌍: ['비군/NNG→피곤/NNG']
#   [3] 저는 친구하고 같이 인사동에 갔어요.
#       시그니처: ['FAP:REP:DS']
#       교정 쌍: ['하고/JKB→와/JKB']
#
# --- 포매팅 결과 ---
# [유사 오류 사례]
# 1. 문장: "저는 네팔에 보커라 갔어요."
#    교정: '에' → '의' (부사격 조사를 관형격 조사로 바꿈)
#    교정: ∅→에/JKB
#
# 2. 문장: "좀 비군해서 저는 집에 갔어요."
#    교정: '비군' → '피곤' (명사를 명사로 철자 오류)
#
# 3. 문장: "저는 친구하고 같이 인사동에 갔어요."
#    교정: '하고' → '와' (부사격 조사를 부사격 조사로 철자 오류)
#
# ...
# 입력: 저는 친구를 같이 영화를 봤어요.
#
# 검색 결과: 10건 (오류 문장만)
#
# --- Raw 검색 결과 (상위 3건) ---
#   [1] 지난주에 우리 반 선생님 같이하고 친구들이 영화관 영화관에서 테이네이터를 봤습니다.
#       시그니처: ['FAP:OM', 'FJC:ADD']
#       교정 쌍: ['∅→과/JKB', '하고/JC→ADD/JC']
#   [2] 제가 학생 때 친구들하고 같이 독일에 가 봤다.
#       시그니처: ['CNP:REP:SH', 'FNP:REP', 'FAP:REP:DS']
#       교정 쌍: ['제/NP→나/NP', '가/JKS→는/JX', '하고/JKB→과/JKB']
# ...

# %% [markdown]
# ## 결과 분석
#
# ### 평가 기준
# 1. 포매팅된 사례가 입력 문장의 오류와 관련이 있는가?
#    -> 연관이 없진 않지만, 가설 3의 문제가 그대로 잔류함.
# 2. 자연어 설명이 LLM이 읽기에 충분히 명확한가?
#    -> 변환이 잘 안 된 부분이 있음. 예를 들면 "'얼마나' → 'ADD' (부사를 부사로 철자 오류)" 같은 경우, ADD라는 문자열은 잘못되었으며, 출자 오류 같은 경우 "부사를 부사로" 같은 문자열은 불필요함.
# 3. raw `correction_pair`의 정보가 손실 없이 변환되었는가?
#    -> 2번에서 작성한 것과 같음.
# ### 각 케이스별 관찰
#
# **1. 오타 (뱡완→병원)**
# - 관찰 결과: 말뭉치에 동일한 케이스가 발견되지 않음.
# - BM25가 오타 단어를 매칭하지 못할 가능성 → 검색 결과 품질 확인 필요
#
# **2. 조사 (를→와)**
# - 관찰 결과: 비교적 적절한 유사 케이스가 검색되는 것 같음. 하지만 보완 필요함.
#
# **3. 어미 (힘든입니다→힘듭니다)**
# - 관찰 결과: 비교적 적절한 유사 케이스가 검색되는 것 같음. 하지만 보완 필요함.
#
# **4. 복합 (월꺼→워커, 아네→안에)**
# - 관찰 결과: 비슷한 케이스가 전혀 없음.
# - 오타가 많은 문장에서의 한계 확인
#
# ### 추가로 보완이 필요해 보이는 부분
# 1. 에러 문장의 위치 정보가 전혀 없음. 예를 들면, "지난주에 우리 반 선생님 같이하고 친구들이 영화관 영화관에서 테이네이터를 봤습니다." 라는 문장이 있다면 어느 위치에서 에러가 발생했는지 원본 말뭉치엔 존재함. 하지만 이 위치 데이터가 사라짐
# 2. 4번 복합 케이스와 같이 유사도가 모두 떨어지는 경우, 차라리 찾지 않는 것이 나을수도 있음, 혹은, 사용자의 다음 입력에서 추론 능력을 높일수도 있을거 같음. 예를 들면
#  - user: 내 월꺼 아네 있는데요
#  - (rag에서 의미 있는 결과를 검색하지 못해, LLM이 자체 평가) bot: 고칠 곳: 월꺼→워커 / 올바르게 다시 입력해 보세요.
#  - user: 내 워커 아네 있는데요
#  - (rag에서 의미 있는 결과를 검색하게 됨. 아네→안에에 해당되는 케이스를 발견)
